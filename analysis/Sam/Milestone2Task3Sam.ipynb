# %%
import FunctionScript
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
df = FunctionScript.LoadnClean("C:\\Users\\samff\\Cosc301Path\\group07-Project\\data\\raw\\defaultofcreditcardclients.csv")
df
# Out:
#        Credit Limit  Sex            Education Marital Status  Age  \
# 1             20000    2                  BSc        Married   24
# 2            120000    2                  BSc         Single   26
# 3             90000    2                  BSc         Single   34
# 4             50000    2                  BSc        Married   37
# 5             50000    1                  BSc        Married   57
# ...             ...  ...                  ...            ...  ...
# 29996        220000    1  High School Diploma        Married   39
# 29997        150000    1  High School Diploma         Single   43
# 29998         30000    1                  BSc         Single   37
# 29999         80000    1  High School Diploma        Married   41
# 30000         50000    1                  BSc        Married   46
#
#        Payment_Score  Avg_Outstanding      Avg_Paid  Default
# 1           0.666667      1284.000000    114.833333        1
# 2           1.500000      2846.166667    833.333333        1
# 3           1.000000     16942.166667   1836.333333        0
# 4           1.000000     38555.666667   1398.000000        0
# 5           0.666667     18223.166667   9841.500000        0
# ...              ...              ...           ...      ...
# 29996       1.000000    120891.500000   7091.666667        0
# 29997       0.333333      3530.333333   2415.000000        0
# 29998       2.333333     11749.333333   5216.666667        1
# 29999       0.833333     44435.166667  24530.166667        1
# 30000       1.000000     38479.000000   1384.666667        1
#
# [29601 rows x 9 columns]

# %%
DF = (FunctionScript.JustPayments("C:\\Users\\samff\\Cosc301Path\\group07-Project\\data\\raw\\defaultofcreditcardclients.csv"))
DF2 = FunctionScript.Defaulters(DF)
DF2
# Out:
#        Credit Limit  Age  PaySep  PayAug  PayJul  PayJun  PayMay  PayApr  \
# 1             20000   24       3       3       0       0      -1      -1
# 2            120000   26       0       3       1       1       1       3
# 14            70000   30       2       3       3       1       1       3
# 17            20000   24       1       1       3       3       3       3
# 22           120000   39       0       0       0       0       0       0
# ...             ...  ...     ...     ...     ...     ...     ...     ...
# 29992        210000   34       4       3       3       3       3       3
# 29995         80000   34       3       3       3       3       3       3
# 29998         30000   37       5       4       3       0       1       1
# 29999         80000   41       2       0       1       1       1       0
# 30000         50000   46       1       1       1       1       1       1
#
#        Outstanding/Sept05  Outstanding/Aug05  ...  Paid/Sept05  Paid/Aug05  \
# 1                    3913               3102  ...            0         689
# 2                    2682               1725  ...            0        1000
# 14                  65802              67369  ...         3200           0
# 17                  15376              18010  ...         3200           0
# 22                    316                316  ...          316         316
# ...                   ...                ...  ...          ...         ...
# 29992                2500               2500  ...            0           0
# 29995               72557              77708  ...         7000        3500
# 29998                3565               3356  ...            0           0
# 29999               -1645              78379  ...        85900        3409
# 30000               47929              48905  ...         2078        1800
#
#        Paid/Jul05  Paid/Jun05  Paid/May05  Paid/Apr05  Default  Payment_Score  \
# 1               0           0           0           0        1       0.666667
# 2            1000        1000           0        2000        1       1.500000
# 14           3000        3000        1500           0        1       2.166667
# 17           1500           0        1650           0        1       2.333333
# 22              0         632         316           0        1       0.000000
# ...           ...         ...         ...         ...      ...            ...
# 29992           0           0           0           0        1       3.166667
# 29995           0        7000           0        4000        1       3.000000
# 29998       22000        4200        2000        3100        1       2.333333
# 29999        1178        1926       52964        1804        1       0.833333
# 30000        1430        1000        1000        1000        1       1.000000
#
#        Avg_Outstanding      Avg_Paid
# 1          1284.000000    114.833333
# 2          2846.166667    833.333333
# 14        56447.500000   1783.333333
# 17        17693.500000   1058.333333
# 22          316.000000    263.333333
# ...                ...           ...
# 29992      2500.000000      0.000000
# 29995     78488.833333   3583.333333
# 29998     11749.333333   5216.666667
# 29999     44435.166667  24530.166667
# 30000     38479.000000   1384.666667
#
# [6636 rows x 24 columns]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(DF.corr(), square=True, center=0.5, yticklabels=True).set_title('Correlation Matrix For Numerical Data')
plt.show()

# %%
#sns.pairplot(data=DF, hue="Default", corner="True")
sns.pairplot(data=DF[['Payment_Score','PaySept','PayAug','PayJul','PayJun','PayMay','PayAPR','Default']],hue='Default',corner='True')

# %%
DF2=FunctionScript.JustPayments("C:\\Users\\samff\\Cosc301Path\\group07-Project\\data\\raw\\defaultofcreditcardclients.csv")

# %%
sns.pairplot(data=df, hue="Default", corner="True")

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), square=True, center=0.5, yticklabels=True).set_title('Correlation Matrix For Numerical Data')
plt.show()

# %%
#plt.subplots(figsize=(14,30))
#ax = sns.boxplot(x='Payment_Score', 
#                 y = 'Avg_Paid', 
#                 data = df)
#bx = sns.stripplot(x='Payment_Score',
#                   y = 'Avg_Paid',
#                   data = df)
#                   #palette="pastel").set(title='Box Plot of Pokemon Weighted scores by type'
                                                   #,xlabel='Cumulative Score %\n (20% HP, 40% Attack, %\n 30% Defence, 10% Speed)'
                                                   #,ylabel='')
#plt.show()

# %%
sns.jointplot(data=df, x='Age', y='Credit Limit',kind = 'hex',color='red')
sns.jointplot(data=df, x='Default', y='Credit Limit',kind = 'hex',color='blue')
sns.despine()

# %%
sns.violinplot(data=df, y='Credit Limit', x='Default').set(title='Payment defaults as a function of credit limit'
                                                   ,xlabel='Payment Defaults)'
                                                   ,ylabel='Credit Limit')
bx = sns.stripplot(x='Default',
                   y = 'Credit Limit',
                   data = df,
                  palette='husl', alpha=0.05)

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
y = df['Default']
x=df['Credit Limit']
z=df['Age']
ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('Credit Limit')
ax.set_ylabel('Default')
ax.set_zlabel('Age')

plt.show()

# %%
sns.violinplot(data=df, y='Payment_Score', x='Default').set(title='Payment defaults as a function of Past Payment "Score"'
                                                   ,xlabel='Payment Defaults)'
                                                   ,ylabel='Payment Score')
bx = sns.stripplot(x='Default',
                   y = 'Payment_Score',
                   data = df,
                  palette='husl', alpha=0.025)
